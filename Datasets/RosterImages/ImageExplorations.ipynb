# %%
import imageio
import numpy as np
import visvis as vv

# %%
AH_img = imageio.imread("AHauck.jfif", as_gray='True')
AJ_img = imageio.imread("ajohnson.jfif", as_gray='True')
DH_img = imageio.imread("dherschel.jfif", as_gray='True')
AO_img = imageio.imread("aortiz.jfif", as_gray='True')
RK_img = imageio.imread("rkulwicki.jfif", as_gray='True')
OW_img = imageio.imread("owasim.jfif", as_gray='True')
GC_img = imageio.imread("GCarvajal.jfif", as_gray='True')
CG_img = imageio.imread("CGarzella.jfif", as_gray='True')
JG_img = imageio.imread("JGaudy.jfif", as_gray='True')
JB_img = imageio.imread("JBulger.jfif", as_gray='True')
print(np.shape(AH_img))
print(np.shape(AJ_img))
print(np.shape(DH_img))
print(np.shape(AO_img))
print(np.shape(RK_img))
print(np.shape(OW_img))
print(np.shape(GC_img))
print(np.shape(CG_img))
print(np.shape(JG_img))
print(np.shape(JB_img))
# Out:
# (770, 575)
# (640, 480)
# (785, 587)
# (640, 480)
# (769, 575)
# (734, 548)
# (1028, 768)
# (640, 480)
# (1098, 818)
# (1407, 1050)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(JG_img, cmap=plt.cm.gray)
plt.show()

# %%
plt.figure()
plt.imshow(CG_img, cmap=plt.cm.gray)
plt.show()

# %%
plt.figure()
plt.imshow(0.5*AJ_img+0.5*AO_img, cmap=plt.cm.gray)
plt.show()

# %%
plt.figure()
plt.imshow(0.25*AJ_img+0.75*AO_img, cmap=plt.cm.gray)
plt.show()

# %%
np.size(AH_img)
# Out:
# 442750

# %%
np.shape(AH_img)
# Out:
# (770, 575)

# %%
np.shape(AJ_img)
# Out:
# (640, 480)
